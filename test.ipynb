# %%
import os
import boto3
from dotenv import load_dotenv
import uuid

# %%
load_dotenv()
AWS_ACCESS_KEY = os.getenv('AWS_ACCESS_KEY_ID')
SECRET_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
REGION = os.getenv('AWS_REGION')
BUCKET = os.getenv('BUCKET')

# %%
# try:
#     if REGION is None:
#         s3_client = boto3.client('s3')
#         s3_client.create_bucket(Bucket=BUCKET)
#     else:
s3_client = boto3.client('s3', region_name=REGION)
#         location = {'LocationConstraint': REGION}
#         s3_client.create_bucket(Bucket=BUCKET,
#                                 CreateBucketConfiguration=location)
# except Exception as e:
#     print(e)

# %%
# Retrieve the list of existing buckets
# s3 = boto3.client('s3')
response = s3_client.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   mindmate-s3

# %%
import os
import sys
import threading

class ProgressPercentage(object):

    def __init__(self, filename):
        self._filename = filename
        self._size = float(os.path.getsize(filename))
        self._seen_so_far = 0
        self._lock = threading.Lock()

    def __call__(self, bytes_amount):
        # To simplify, assume this is hooked up to a single filename
        with self._lock:
            self._seen_so_far += bytes_amount
            percentage = (self._seen_so_far / self._size) * 100
            sys.stdout.write(
                "\r%s  %s / %s  (%.2f%%)" % (
                    self._filename, self._seen_so_far, self._size,
                    percentage))
            sys.stdout.flush()

# %%
FILE_PATH = "uploads/image.png"
unique_id = uuid.uuid4().hex
S3_OBJECT_NAME = f"uploads/{unique_id}.jpg"

# %%
s3_client.upload_file(FILE_PATH, BUCKET, S3_OBJECT_NAME,    Callback=ProgressPercentage(FILE_PATH))

print(f"File uploaded with unique name: {S3_OBJECT_NAME}")
# Out:
# uploads/image.png  184971 / 184971.0  (100.00%)File uploaded with unique name: uploads/da469b84bda54d379c3e326faf2ebe9a.jpg

# %%
s3_client.download_file(BUCKET,S3_OBJECT_NAME,FILE_PATH)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s3_client.download_file(BUCKET,S3_OBJECT_NAME,FILE_PATH)
#
# File ~/PycharmProjects/MindMate/.venv/lib/python3.10/site-packages/botocore/context.py:124, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122 if hook:
#     123     hook()
# --> 124 return func(*args, **kwargs)
#
# File ~/PycharmProjects/MindMate/.venv/lib/python3.10/site-packages/boto3/s3/inject.py:218, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     183 """Download an S3 object to a file.
#     184
#     185 Usage::
#    (...)
#     215     transfer.
#     216 """
#     217 with S3Transfer(self, Config) as transfer:
# --> 218     return transfer.download_file(
#     219         bucket=Bucket,
#     220         key=Key,
#     221         filename=Filename,
# ...
