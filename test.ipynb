# %%
import os
import boto3
from dotenv import load_dotenv
import uuid

# %%
load_dotenv()
AWS_ACCESS_KEY = os.getenv('AWS_ACCESS_KEY_ID')
SECRET_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
REGION = os.getenv('AWS_REGION')
BUCKET = os.getenv('BUCKET')

# %%
# try:
#     if REGION is None:
#         s3_client = boto3.client('s3')
#         s3_client.create_bucket(Bucket=BUCKET)
#     else:
s3_client = boto3.client('s3', region_name=REGION)
#         location = {'LocationConstraint': REGION}
#         s3_client.create_bucket(Bucket=BUCKET,
#                                 CreateBucketConfiguration=location)
# except Exception as e:
#     print(e)

# %%
# Retrieve the list of existing buckets
# s3 = boto3.client('s3')
response = s3_client.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Existing buckets:
#   mindmate-s3

# %%
import os
import sys
import threading

class ProgressPercentage(object):

    def __init__(self, filename):
        self._filename = filename
        self._size = float(os.path.getsize(filename))
        self._seen_so_far = 0
        self._lock = threading.Lock()

    def __call__(self, bytes_amount):
        # To simplify, assume this is hooked up to a single filename
        with self._lock:
            self._seen_so_far += bytes_amount
            percentage = (self._seen_so_far / self._size) * 100
            sys.stdout.write(
                "\r%s  %s / %s  (%.2f%%)" % (
                    self._filename, self._seen_so_far, self._size,
                    percentage))
            sys.stdout.flush()

# %%
FILE_PATH = "uploads/image.png"
unique_id = uuid.uuid4().hex
S3_OBJECT_NAME = f"uploads/{unique_id}.jpg"

# %%
s3_client.upload_file(FILE_PATH, BUCKET, S3_OBJECT_NAME,    Callback=ProgressPercentage(FILE_PATH))

print(f"File uploaded with unique name: {S3_OBJECT_NAME}")
# Out:
# uploads/image.png  184971 / 184971.0  (100.00%)File uploaded with unique name: uploads/da469b84bda54d379c3e326faf2ebe9a.jpg

# %%
s3_client.download_file(BUCKET,S3_OBJECT_NAME,FILE_PATH)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s3_client.download_file(BUCKET,S3_OBJECT_NAME,FILE_PATH)
#
# File ~/PycharmProjects/MindMate/.venv/lib/python3.10/site-packages/botocore/context.py:124, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122 if hook:
#     123     hook()
# --> 124 return func(*args, **kwargs)
#
# File ~/PycharmProjects/MindMate/.venv/lib/python3.10/site-packages/boto3/s3/inject.py:218, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     183 """Download an S3 object to a file.
#     184
#     185 Usage::
#    (...)
#     215     transfer.
#     216 """
#     217 with S3Transfer(self, Config) as transfer:
# --> 218     return transfer.download_file(
#     219         bucket=Bucket,
#     220         key=Key,
#     221         filename=Filename,
# ...

# %%
import pandas as pd
import random

# Generating synthetic data
num_records = 100

def random_yes_no():
    return random.choice(["Yes", "No"])

def random_irrigation():
    return random.choice(["Drip", "Sprinkler", "Flood", "Manual"])

def random_power_source():
    return random.choice(["Electric", "Solar", "Diesel", "Manual"])

def random_fencing_status():
    return random.choice(["Complete", "Incomplete", "Under Repair"])

def random_manure():
    return random.choice(["Compost", "Chemical Fertilizer", "Cow Dung", "Vermicompost", "None"])

def random_spraying():
    return random.choice(["Pesticide A - 2L/acre", "Fungicide B - 1.5L/acre", "Herbicide C - 3L/acre", "None"])

def random_woody_plantation():
    return random.choice(["Teak - 1 acre", "Mahogany - 2 acres", "Eucalyptus - 1.5 acres", "None"])

# Creating a DataFrame
farm_data = pd.DataFrame({
    "Maximum Temperature (°C)": [random.randint(25, 40) for _ in range(num_records)],
    "Minimum Temperature (°C)": [random.randint(10, 25) for _ in range(num_records)],
    "Wind Speed (km/h)": [random.randint(0, 20) for _ in range(num_records)],
    "Humidity (%)": [random.randint(30, 90) for _ in range(num_records)],
    "Rainfall Occurrence": [random_yes_no() for _ in range(num_records)],
    "Number of Napier plants planted": [random.randint(50, 500) for _ in range(num_records)],
    "Plant Spacing Details": [random.choice(["30 cm x 30 cm", "40 cm x 40 cm", "50 cm x 50 cm"]) for _ in range(num_records)],
    "Total Acreage Planted with Napier": [round(random.uniform(0.5, 5.0), 2) for _ in range(num_records)],
    "Other Crop Sowing Details": [random.choice(["Maize", "Wheat", "Sugarcane", "None"]) for _ in range(num_records)],
    "Total Acres Irrigated": [round(random.uniform(0.5, 10.0), 2) for _ in range(num_records)],
    "Type of Irrigation Used": [random_irrigation() for _ in range(num_records)],
    "Power Source Utilized": [random_power_source() for _ in range(num_records)],
    "Status of Fencing": [random_fencing_status() for _ in range(num_records)],
    "Type of Manure Applied": [random_manure() for _ in range(num_records)],
    "Area Where Manure Was Applied (acres)": [round(random.uniform(0, 3), 2) for _ in range(num_records)],
    "Land Preparation Area (acres)": [round(random.uniform(0.5, 5.0), 2) for _ in range(num_records)],
    "Weeding Area and Crop Details": [random.choice(["1 acre - Maize", "2 acres - Wheat", "None"]) for _ in range(num_records)],
    "Diesel Consumption Details (Liters)": [random.randint(5, 50) for _ in range(num_records)],
    "Total Number of Labourers (Day/Night)": [random.randint(5, 20) for _ in range(num_records)],
    "Spraying Details": [random_spraying() for _ in range(num_records)],
    "Woody Plantation Type and Area (acres)": [random_woody_plantation() for _ in range(num_records)],
    "Next Day's Work Schedule": [random.choice(["Plowing", "Irrigation", "Harvesting", "None"]) for _ in range(num_records)],
    "Pending Tasks": [random.choice(["Weeding", "Fertilizer Application", "Repair Fencing", "None"]) for _ in range(num_records)],
    "Remarks/Additional Comments": [random.choice(["Good growth", "Pests detected", "Needs more water", "No issues"]) for _ in range(num_records)]
})

# Displaying a sample of the dataset
print(farm_data.head())
# Out:
#    Maximum Temperature (°C)  Minimum Temperature (°C)  Wind Speed (km/h)  \
# 0                        25                        16                 20
# 1                        34                        12                  2
# 2                        27                        16                  4
# 3                        38                        22                  1
# 4                        31                        22                  4
#
#    Humidity (%) Rainfall Occurrence  Number of Napier plants planted  \
# 0            53                  No                               81
# 1            50                 Yes                              271
# 2            83                  No                              384
# 3            41                  No                              459
# 4            63                 Yes                               73
#
#   Plant Spacing Details  Total Acreage Planted with Napier  \
# ...
